# %%
from google.auth.transport.requests import Request
from google.oauth2.service_account import Credentials

# %%
key_path='C:\\Users\\khand\\Downloads\\medlm-448718-99b78a844357.json'

# %%
credentials = Credentials.from_service_account_file(key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"])

# %%
PROJECT_ID ='helpful-kingdom-448718-u1'
REGION ='us-central1'

# %%
# !pip install -U google-cloud-aiplatform "shapely<2"
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.6
#     Uninstalling shapely-2.0.6:
#       Successfully uninstalled shapely-2.0.6
# ...

# %%
import vertexai
vertexai.init(project=PROJECT_ID, location=REGION, credentials=credentials)

# %%
from vertexai.language_models import TextGenerationModel
generation_model = TextGenerationModel.from_pretrained("medlm-medium")
# Out:
# ---------------------------------------------------------------------------
# PermissionDenied                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 from vertexai.language_models import TextGenerationModel
# ----> 2 generation_model = TextGenerationModel.from_pretrained("medlm-medium")
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\vertexai\_model_garden\_model_garden_models.py:289, in _ModelGardenModel.from_pretrained(cls, model_name)
#     278 credential_exception_str = (
#     279     "\nUnable to authenticate your request."
#     280     "\nDepending on your runtime environment, you can complete authentication by:"
#    (...)
#     285     "\n- if in service account or other: please follow guidance in https://cloud.google.com/docs/authentication"
#     286 )
#     288 try:
# --> 289     return _from_pretrained(interface_class=cls, model_name=model_name)
#     290 except auth_exceptions.GoogleAuthError as e:
# ...
