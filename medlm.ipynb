# %%
import IPython
app = IPython.Application.instance()

# %%
import vertexai
from vertexai.preview.language_models import TextGenerationModel


# TODO: Replace with project ID from Cloud Console
# (https://support.google.com/googleapi/answer/7014113)
PROJECT_ID = 'helpful-kingdom-448718-u1'

# MedLM models are only available in us-central1.
vertexai.init(project=PROJECT_ID, location='us-central1')

parameters = {
    "candidate_count": 1,
    "max_output_tokens": 256,
    "temperature": 0.0,
    "top_k": 40,
    "top_p": 0.80,
}

model_instance = TextGenerationModel.from_pretrained("medlm-medium")
response = model_instance.predict(
    "Question: What causes you to get ringworm?",
    **parameters
)

print(f"Response from Model: {response.text}")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\vertexai\_model_garden\_model_garden_models.py:289, in _ModelGardenModel.from_pretrained(cls, model_name)
#     288 try:
# --> 289     return _from_pretrained(interface_class=cls, model_name=model_name)
#     290 except auth_exceptions.GoogleAuthError as e:
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\vertexai\_model_garden\_model_garden_models.py:206, in _from_pretrained(interface_class, model_name, publisher_model, tuned_vertex_model)
#     202         raise ValueError(
#     203             f"Class {interface_class} is not a correct model interface class since it does not have an instance schema URI."
#     204         )
# --> 206     model_info = _get_model_info(
#     207         model_id=model_name,
#     208         schema_to_class_map={interface_class._INSTANCE_SCHEMA_URI: interface_class},
#     209     )
#     211 else:
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\vertexai\_model_garden\_model_garden_models.py:122, in _get_model_info(model_id, schema_to_class_map, interface_class, publisher_model_res, tuned_vertex_model)
#     120 if not publisher_model_res:
#     121     publisher_model_res = (
# --> 122         _publisher_models._PublisherModel(  # pylint: disable=protected-access
#     123             resource_name=model_id
#     124         )._gca_resource
#     125     )
#     127 if not publisher_model_res.name.startswith("publishers/google/models/"):
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\google\cloud\aiplatform\_publisher_models.py:63, in _PublisherModel.__init__(self, resource_name, project, location, credentials)
#      44 """Retrieves an existing PublisherModel resource given a resource name or model garden id.
#      45
#      46 Args:
#    (...)
#      60         Overrides credentials set in aiplatform.init.
#      61 """
# ---> 63 super().__init__(project=project, location=location, credentials=credentials)
#      65 if self._parse_resource_name(resource_name):
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\google\cloud\aiplatform\base.py:558, in VertexAiResourceNoun.__init__(self, project, location, credentials, resource_name)
#     557 self.location = location or initializer.global_config.location
# --> 558 self.credentials = credentials or initializer.global_config.credentials
#     560 appended_user_agent = None
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\google\cloud\aiplatform\initializer.py:392, in _Config.credentials(self)
#     391 logger.addFilter(logging_warning_filter)
# --> 392 self._set_project_as_env_var_or_google_auth_default()
#     393 credentials = self._credentials
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\google\cloud\aiplatform\initializer.py:117, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     116 if not self._credentials and not self._api_key:
# --> 117     credentials, _ = google.auth.default()
#     118     self._credentials = credentials
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\google\auth\_default.py:697, in default(scopes, request, quota_project_id, default_scopes)
#     695         return credentials, effective_project_id
# --> 697 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.
#
# The above exception was the direct cause of the following exception:
#
# GoogleAuthError                           Traceback (most recent call last)
# Cell In[5], line 20
#      10 vertexai.init(project=PROJECT_ID, location='us-central1')
#      12 parameters = {
#      13     "candidate_count": 1,
#      14     "max_output_tokens": 256,
#    (...)
#      17     "top_p": 0.80,
#      18 }
# ---> 20 model_instance = TextGenerationModel.from_pretrained("medlm-medium")
#      21 response = model_instance.predict(
#      22     "Question: What causes you to get ringworm?",
#      23     **parameters
#      24 )
#      26 print(f"Response from Model: {response.text}")
#
# File c:\Users\khand\anaconda3\envs\llms\Lib\site-packages\vertexai\_model_garden\_model_garden_models.py:291, in _ModelGardenModel.from_pretrained(cls, model_name)
#     289     return _from_pretrained(interface_class=cls, model_name=model_name)
#     290 except auth_exceptions.GoogleAuthError as e:
# --> 291     raise auth_exceptions.GoogleAuthError(credential_exception_str) from e
#
# GoogleAuthError:
# Unable to authenticate your request.
# Depending on your runtime environment, you can complete authentication by:
# - if in local JupyterLab instance: `!gcloud auth login`
# - if in Colab:
#     -`from google.colab import auth`
#     -`auth.authenticate_user()`
# - if in service account or other: please follow guidance in https://cloud.google.com/docs/authentication

# %%
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=RWQXIa1u8mfpTY3MKeOKSkOd3qn1IJ&access_type=offline&code_challenge=vKYbEaFHXS_HpsHQdkBfXGfpXI97AzKfoBBCsHJ9oe4&code_challenge_method=S256
#
#
# You are now logged in as [keshavkh.2004@gmail.com].
# Your current project is [helpful-kingdom-448718-u1].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !pip install google.colab
# Out:
# ERROR: Could not find a version that satisfies the requirement google.colab (from versions: none)
# ERROR: No matching distribution found for google.colab

# %%
from google.colab import auth
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import auth
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
auth.authenticate_user()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 auth.authenticate_user()
#
# NameError: name 'auth' is not defined
